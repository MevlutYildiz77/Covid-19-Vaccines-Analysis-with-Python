# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("country_vaccinations.csv")
df.head()
# Out:
#        country iso_code  Month  Week       date  total_vaccinations  \
# 0  Afghanistan      AFG      2     9  2/22/2021                 0.0
# 1  Afghanistan      AFG      2     9  2/23/2021                 NaN
# 2  Afghanistan      AFG      2     9  2/24/2021                 NaN
# 3  Afghanistan      AFG      2     9  2/25/2021                 NaN
# 4  Afghanistan      AFG      2     9  2/26/2021                 NaN
#
#    people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                0.0                      NaN                     NaN
# 1                NaN                      NaN                     NaN
# 2                NaN                      NaN                     NaN
# 3                NaN                      NaN                     NaN
# 4                NaN                      NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    daily_vaccinations_per_million  \
# 0                             NaN
# 1                            35.0
# 2                            35.0
# 3                            35.0
# 4                            35.0
#
#                                             vaccines  \
# 0  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 1  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 2  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 3  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 4  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/
# 3  World Health Organization  https://covid19.who.int/
# 4  World Health Organization  https://covid19.who.int/

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17607 entries, 0 to 17606
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              17607 non-null  object
#  1   iso_code                             17607 non-null  object
#  2   Month                                17607 non-null  int64
#  3   Week                                 17607 non-null  int64
#  4   date                                 17607 non-null  object
#  5   total_vaccinations                   10251 non-null  float64
#  6   people_vaccinated                    9526 non-null   float64
#  7   people_fully_vaccinated              7185 non-null   float64
#  8   daily_vaccinations_raw               8568 non-null   float64
#  9   daily_vaccinations                   17391 non-null  float64
#  10  total_vaccinations_per_hundred       10251 non-null  float64
#  11  people_vaccinated_per_hundred        9526 non-null   float64
#  12  people_fully_vaccinated_per_hundred  7185 non-null   float64
#  13  daily_vaccinations_per_million       17391 non-null  float64
#  14  vaccines                             17607 non-null  object
#  15  source_name                          17607 non-null  object
#  16  source_website                       17607 non-null  object
# dtypes: float64(9), int64(2), object(6)
# memory usage: 2.3+ MB

# %%
pd.to_datetime(df.date)
# Out:
# 0       2021-02-22
# 1       2021-02-23
# 2       2021-02-24
# 3       2021-02-25
# 4       2021-02-26
#            ...
# 17602   2021-05-08
# 17603   2021-05-09
# 17604   2021-05-10
# 17605   2021-05-11
# 17606   2021-05-12
# Name: date, Length: 17607, dtype: datetime64[ns]

# %%
df.country.value_counts()
# Out:
# Norway                       162
# Canada                       151
# Russia                       150
# China                        150
# Israel                       146
#                             ...
# Sint Maarten (Dutch part)      1
# Central African Republic       1
# Madagascar                     1
# Yemen                          1
# Tajikistan                     1
# Name: country, Length: 211, dtype: int64

# %%
df.vaccines.value_counts(dropna=False)
# Out:
# Oxford/AstraZeneca                                                                    3146
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                          2265
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                         1896
# Oxford/AstraZeneca, Pfizer/BioNTech                                                   1412
# Pfizer/BioNTech                                                                       1184
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                           892
# Moderna, Pfizer/BioNTech                                                               799
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                      775
# Oxford/AstraZeneca, Sinopharm/Beijing                                                  667
# Sputnik V                                                                              499
# Oxford/AstraZeneca, Sinovac                                                            316
# Sinopharm/Beijing                                                                      292
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing                                 271
# Pfizer/BioNTech, Sinopharm/Beijing                                                     208
# Pfizer/BioNTech, Sinovac                                                               202
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V                                199
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac                                         197
# EpiVacCorona, Sputnik V                                                                150
# Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac                                            150
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                                       148
# Johnson&Johnson, Moderna, Pfizer/BioNTech                                              145
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V                       140
# Oxford/AstraZeneca, Sputnik V                                                          139
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V             137
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing                                         130
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V     129
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech                                   127
# Covaxin, Oxford/AstraZeneca                                                            120
# Moderna, Oxford/AstraZeneca                                                            118
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik V                              108
# Sinopharm/Beijing, Sputnik V                                                           103
# CanSino, Sinopharm/Beijing, Sinovac, Sputnik V                                         101
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                               92
# Johnson&Johnson                                                                         87
# Pfizer/BioNTech, Sputnik V                                                              75
# Oxford/AstraZeneca, Sinovac, Sputnik V                                                  73
# Pfizer/BioNTech, Sinovac, Sputnik V                                                     60
# Moderna, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                               29
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V                24
# EpiVacCorona, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                           1
# Abdala                                                                                   1
# Name: vaccines, dtype: int64

# %%
df = df[["vaccines", "country"]]
df.head()
# Out:
#                                             vaccines      country
# 0  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...  Afghanistan
# 1  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...  Afghanistan
# 2  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...  Afghanistan
# 3  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...  Afghanistan
# 4  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...  Afghanistan

# %%
dict_ = {}
for i in df.vaccines.unique():
    dict_[i]  = [df["country"][j] for j in df[df["vaccines"] ==i].index]

vaccines = {}
for key, value in dict_.items():
    vaccines[key] = set(value)
for i, j in vaccines.items():
    print(f"{i}:>>{j}")
# Out:
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing:>>{'Afghanistan', 'Maldives', 'Peru'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Albania', 'Bosnia and Herzegovina'}
# Sputnik V:>>{'Venezuela', 'Paraguay', 'Armenia', 'Kazakhstan', 'Algeria', 'Syria', 'Belarus', 'Guinea'}
# Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Jersey', 'Oman', 'Cayman Islands', 'Sweden', 'Isle of Man', 'Slovenia', 'Cape Verde', 'Andorra', 'Costa Rica', 'South Korea', 'Saudi Arabia', 'Panama', 'Australia'}
# Oxford/AstraZeneca:>>{'Dominica', 'Togo', 'Democratic Republic of Congo', 'Liberia', "Cote d'Ivoire", 'Belize', 'Ethiopia', 'Bangladesh', 'Barbados', 'Fiji', 'Tajikistan', 'Sao Tome and Principe', 'Uzbekistan', 'Bahamas', 'South Sudan', 'Taiwan', 'Tonga', 'Trinidad and Tobago', 'Mali', 'Kosovo', 'Grenada', 'New Caledonia', 'Wallis and Futuna', 'Papua New Guinea', 'Solomon Islands', 'Angola', 'Myanmar', 'Sudan', 'Saint Lucia', 'Tuvalu', 'Gambia', 'Nauru', 'Anguilla', 'Saint Kitts and Nevis', 'Yemen', 'French Polynesia', 'Eswatini', 'Saint Helena', 'Georgia', 'Lesotho', 'Zambia', 'Timor', 'Uganda', 'Samoa', 'Brunei', 'Madagascar', 'Nigeria', 'Sierra Leone', 'Montserrat', 'Suriname', 'Botswana', 'Guyana', 'Vietnam', 'Bhutan', 'Saint Vincent and the Grenadines', 'Malawi', 'Falkland Islands', 'Jamaica', 'Antigua and Barbuda', 'Ghana'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Djibouti', 'Argentina'}
# Pfizer/BioNTech:>>{'Gibraltar', 'New Zealand', 'Aruba', 'Kuwait', 'Slovakia', 'Monaco', 'Bermuda', 'Turks and Caicos Islands', 'Qatar', 'Japan', 'Greenland'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Latvia', 'Germany', 'Netherlands', 'Italy', 'Poland', 'Lithuania', 'Ireland', 'Romania', 'Spain', 'Belgium', 'Czechia', 'Austria', 'Bulgaria', 'France'}
# Oxford/AstraZeneca, Sinovac:>>{'Thailand', 'Indonesia', 'Azerbaijan', 'Benin'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Serbia', 'Lebanon', 'Bolivia', 'Moldova', 'Bahrain', 'Montenegro', 'North Macedonia', 'Mongolia'}
# Moderna, Pfizer/BioNTech:>>{'Denmark', 'Singapore', 'Israel', 'Bonaire Sint Eustatius and Saba', 'Liechtenstein', 'Curacao', 'Faeroe Islands', 'Switzerland'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac:>>{'Chile', 'Uruguay', 'El Salvador', 'Ecuador', 'Colombia', 'Ukraine', 'Brazil', 'Northern Cyprus', 'Malaysia'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac:>>{'Cambodia', 'Somalia', 'Dominican Republic'}
# Sinopharm/Beijing:>>{'Equatorial Guinea', 'Mauritania', 'Gabon', 'Zimbabwe', 'Senegal', 'Cameroon'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Iceland', 'Palestine', 'United Kingdom', 'England', 'Wales', 'Croatia', 'Estonia', 'Greece', 'Guernsey', 'Sint Maarten (Dutch part)', 'Northern Ireland', 'Luxembourg', 'Portugal', 'Finland', 'Norway', 'Scotland', 'Rwanda', 'Canada', 'Malta'}
# Covaxin, Oxford/AstraZeneca:>>{'Central African Republic', 'India'}
# Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac:>>{'China'}
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing:>>{'Comoros', 'Mauritius'}
# Moderna, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Congo'}
# Abdala:>>{'Cuba'}
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Cyprus'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Egypt'}
# Moderna, Oxford/AstraZeneca:>>{'Honduras', 'Guatemala'}
# Oxford/AstraZeneca, Sinopharm/Beijing:>>{'Niger', 'Mozambique', 'Nepal', 'Sri Lanka', 'Morocco', 'Guinea-Bissau', 'Iraq', 'Namibia', 'Seychelles'}
# Pfizer/BioNTech, Sinovac:>>{'Hong Kong', 'Turkey'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Hungary'}
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Iran'}
# Pfizer/BioNTech, Sinopharm/Beijing:>>{'Macao', 'Jordan'}
# Oxford/AstraZeneca, Sputnik V:>>{'Kenya', 'Nicaragua'}
# Sinopharm/Beijing, Sputnik V:>>{'Laos', 'Kyrgyzstan'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V:>>{'Libya'}
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Mexico'}
# CanSino, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Pakistan'}
# Oxford/AstraZeneca, Sinovac, Sputnik V:>>{'Philippines'}
# EpiVacCorona, Sputnik V:>>{'Russia'}
# Pfizer/BioNTech, Sputnik V:>>{'San Marino'}
# Johnson&Johnson:>>{'South Africa'}
# Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Tunisia'}
# EpiVacCorona, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Turkmenistan'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V:>>{'United Arab Emirates'}
# Johnson&Johnson, Moderna, Pfizer/BioNTech:>>{'United States'}

# %%
import plotly.express as px
import plotly.offline as py

vaccine_map = px.choropleth(df,  locations = 'country', color = 'vaccines')
vaccine_map.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})
vaccine_map.show()
